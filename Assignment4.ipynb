# %% [markdown]
# # Assignment 4
# DATA 1202

# %%
#Import Python Libraries
import numpy as np
import pandas as pd

# %%
#load the given dataset
df_raw = pd.read_excel('youtube_dataset.xlsx')
df_raw
# Out:
#      web-scraper-order                              web-scraper-start-url  \
# 0      1553043067-5148  https://socialblade.com/youtube/top/5000/mosts...
# 1      1553043063-5147  https://socialblade.com/youtube/top/5000/mosts...
# 2      1553043059-5146  https://socialblade.com/youtube/top/5000/mosts...
# 3      1553043055-5145  https://socialblade.com/youtube/top/5000/mosts...
# 4      1553043051-5144  https://socialblade.com/youtube/top/5000/mosts...
# ...                ...                                                ...
# 3939   1553037913-3921  https://socialblade.com/youtube/top/5000/mosts...
# 3940    1553024302-913  https://socialblade.com/youtube/top/5000/mosts...
# 3941   1553034470-3276  https://socialblade.com/youtube/top/5000/mosts...
# 3942   1553040011-4402  https://socialblade.com/youtube/top/5000/mosts...
# 3943   1553027486-1650  https://socialblade.com/youtube/top/5000/mosts...
#
#                       userID  \
# 0                  PewDiePie
# ...

# %%
#creating the subset for data selecting using iloc function for top 1000 records
df_filtered = df_raw.iloc[:1000,:]

# %%
df_filtered.head(5)
# Out:
#   web-scraper-order                              web-scraper-start-url  \
# 0   1553043067-5148  https://socialblade.com/youtube/top/5000/mosts...
# 1   1553043063-5147  https://socialblade.com/youtube/top/5000/mosts...
# 2   1553043059-5146  https://socialblade.com/youtube/top/5000/mosts...
# 3   1553043055-5145  https://socialblade.com/youtube/top/5000/mosts...
# 4   1553043051-5144  https://socialblade.com/youtube/top/5000/mosts...
#
#            userID                                        userID-href  \
# 0       PewDiePie        https://socialblade.com/youtube/c/pewdiepie
# 1        T-Series     https://socialblade.com/youtube/c/tseriesmusic
# 2          Gaming  https://socialblade.com/youtube/channel/UCOpNc...
# 3  YouTube Movies  https://socialblade.com/youtube/channel/UClgRk...
# 4          Sports  https://socialblade.com/youtube/channel/UCEgdi...
#
#              name  uploads  subscribers   videoviews country    channeltype  \
# ...

# %%
#converting the dataframe with 1000 records to new separate csv
df_filtered.to_csv("Filtered.csv")

# %%
#creating the function for calculating the distribution of channel type for top 1000 rows
def Dist_of_Ch():
    x = df_raw.iloc[:1000,:]['channeltype'].value_counts()
    print(x)
Dist_of_Ch()
# Out:
# Entertainment    284
# Music            240
# Games            115
# Comedy            76
# People            72
# Howto             49
# Film              36
# Education         30
# Tech              19
# Sports            17
# News              17
# Autos              3
# Animals            2
# Nonprofit          1
# Travel             1
# Name: channeltype, dtype: int64

# %%
#calling the created function 
dis= Dist_of_Ch()
# Out:
# Entertainment    284
# Music            240
# Games            115
# Comedy            76
# People            72
# Howto             49
# Film              36
# Education         30
# Tech              19
# Sports            17
# News              17
# Autos              3
# Animals            2
# Nonprofit          1
# Travel             1
# Name: channeltype, dtype: int64
